# %% [markdown]
# <a href="https://colab.research.google.com/github/danielli-arcari/analisededados_populacaoprisionalMG_2017a2024/blob/main/analisededados_populacaoprisionalMG_2017a2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('/content/drive/MyDrive/Notebooks_projetos/Dados Abertos_Pop_Pris_Sexo_Escolaridade_Jan_2017_Jun_2024.xlsx')
df.head(30)
# Out:
#     COD_OBSERVATORIO                 NOME_ESTAB_PRISIONAL  COD_INSTITUICAO  \
# 0              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 1              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 2              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 3              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 4              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 5              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 6              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 7              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 8              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 9              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 10             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 11             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 12             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 13             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 14             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 15             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 16             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 17             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 18             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 19             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 20             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 21             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 22             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 23             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 24             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 25             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 26             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 27             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 28             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 29             40159  Anexo Prisao Civil Ceresp Gameleira                4
#
#    INSTITUICAO  COD_IBGE       MUNICIPIO  COD_RISP                       RISP  \
# 0        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 1        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 2        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 3        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 4        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 5        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 6        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 7        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 8        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 9        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 10       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 11       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 12       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 13       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 14       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 15       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 16       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 17       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 18       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 19       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 20       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 21       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 22       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 23       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 24       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 25       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 26       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 27       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 28       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 29       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
#
#     COD_SEXO SEXO_NA_ADMISSAO  COD_ESCOLARIDADE_NA_ADMISSAO  \
# 0          1        Masculino                             1
# 1          1        Masculino                             1
# 2          1        Masculino                             1
# 3          1        Masculino                             1
# 4          1        Masculino                             2
# 5          1        Masculino                             2
# 6          1        Masculino                             2
# 7          1        Masculino                             2
# 8          1        Masculino                             2
# 9          1        Masculino                             2
# 10         1        Masculino                             2
# 11         1        Masculino                             2
# 12         1        Masculino                             2
# 13         1        Masculino                             3
# 14         1        Masculino                             3
# 15         1        Masculino                             3
# 16         1        Masculino                             3
# 17         1        Masculino                             3
# 18         1        Masculino                             3
# 19         1        Masculino                             3
# 20         1        Masculino                             3
# 21         1        Masculino                             3
# 22         1        Masculino                             3
# 23         1        Masculino                             3
# 24         1        Masculino                             4
# 25         1        Masculino                             4
# 26         1        Masculino                             4
# 27         1        Masculino                             4
# 28         1        Masculino                             4
# 29         1        Masculino                             4
#
#    ESCOLARIDADE_NA_ADMISSAO   ANO  MES_NUMERICO  CONTAGEM_IPL
# 0                Analfabeto  2017             1             0
# 1                Analfabeto  2017             1             0
# 2                Analfabeto  2017             1             0
# 3                Analfabeto  2017             1             0
# 4         Semi-Alfabetizado  2017             1             0
# 5         Semi-Alfabetizado  2017             1             0
# 6         Semi-Alfabetizado  2017             1             0
# 7         Semi-Alfabetizado  2017             1             1
# 8         Semi-Alfabetizado  2017             1             1
# 9         Semi-Alfabetizado  2017             1             0
# 10        Semi-Alfabetizado  2017             1             1
# 11        Semi-Alfabetizado  2017             1             0
# 12        Semi-Alfabetizado  2017             1             1
# 13        1.Grau Incompleto  2017             1             0
# 14        1.Grau Incompleto  2017             1             0
# 15        1.Grau Incompleto  2017             1             2
# 16        1.Grau Incompleto  2017             1             1
# 17        1.Grau Incompleto  2017             1             6
# 18        1.Grau Incompleto  2017             1             2
# 19        1.Grau Incompleto  2017             1             4
# 20        1.Grau Incompleto  2017             1             0
# 21        1.Grau Incompleto  2017             1             0
# 22        1.Grau Incompleto  2017             1             0
# 23        1.Grau Incompleto  2017             1             0
# 24          1.Grau Completo  2017             1             0
# 25          1.Grau Completo  2017             1             0
# 26          1.Grau Completo  2017             1             1
# 27          1.Grau Completo  2017             1             2
# 28          1.Grau Completo  2017             1             2
# 29          1.Grau Completo  2017             1             1

# %%
#Etapa1 - Inspecionando o dataframe:
#Verificando número de linhas e colunas:
df.shape
# Out:
# (328773, 15)

# %%
#Verificando tipo de dados:
df.dtypes
# Out:
# COD_OBSERVATORIO                 int64
# NOME_ESTAB_PRISIONAL            object
# COD_INSTITUICAO                  int64
# INSTITUICAO                     object
# COD_IBGE                         int64
# MUNICIPIO                       object
# COD_RISP                         int64
# RISP                            object
# COD_SEXO                         int64
# SEXO_NA_ADMISSAO                object
# COD_ESCOLARIDADE_NA_ADMISSAO     int64
# ESCOLARIDADE_NA_ADMISSAO        object
# ANO                              int64
# MES_NUMERICO                     int64
# CONTAGEM_IPL                     int64
# dtype: object

# %%
#verificando se há dados nulos:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328773 entries, 0 to 328772
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   COD_OBSERVATORIO              328773 non-null  int64
#  1   NOME_ESTAB_PRISIONAL          328773 non-null  object
#  2   COD_INSTITUICAO               328773 non-null  int64
#  3   INSTITUICAO                   328773 non-null  object
#  4   COD_IBGE                      328773 non-null  int64
#  5   MUNICIPIO                     328773 non-null  object
#  6   COD_RISP                      328773 non-null  int64
#  7   RISP                          328773 non-null  object
#  8   COD_SEXO                      328773 non-null  int64
#  9   SEXO_NA_ADMISSAO              328773 non-null  object
#  10  COD_ESCOLARIDADE_NA_ADMISSAO  328773 non-null  int64
#  11  ESCOLARIDADE_NA_ADMISSAO      328773 non-null  object
#  12  ANO                           328773 non-null  int64
#  13  MES_NUMERICO                  328773 non-null  int64
#  14  CONTAGEM_IPL                  328773 non-null  int64
# dtypes: int64(9), object(6)
# memory usage: 37.6+ MB

# %%
df.describe(include='all')
# Out:
#         COD_OBSERVATORIO                             NOME_ESTAB_PRISIONAL  \
# count      328773.000000                                           328773
# unique               NaN                                              268
# top                  NaN  Penitenciária Prof. Aluízio Ignácio de Oliveira
# freq                 NaN                                             2626
# mean        42693.587959                                              NaN
# std          6681.311569                                              NaN
# min         40002.000000                                              NaN
# 25%         40074.000000                                              NaN
# 50%         40132.000000                                              NaN
# 75%         40200.000000                                              NaN
# max         60066.000000                                              NaN
#
#         COD_INSTITUICAO INSTITUICAO       COD_IBGE           MUNICIPIO  \
# count     328773.000000      328773  328773.000000              328773
# unique              NaN           2            NaN                 188
# top                 NaN       DEPEN            NaN  Ribeirão das Neves
# freq                NaN      286254            NaN               11245
# mean           4.258653         NaN  313780.325088                 NaN
# std            0.671123         NaN    2139.980429                 NaN
# min            4.000000         NaN  310020.000000                 NaN
# 25%            4.000000         NaN  311910.000000                 NaN
# 50%            4.000000         NaN  313900.000000                 NaN
# 75%            4.000000         NaN  315460.000000                 NaN
# max            6.000000         NaN  317200.000000                 NaN
#
#              COD_RISP                 RISP       COD_SEXO SEXO_NA_ADMISSAO  \
# count   328773.000000               328773  328773.000000           328773
# unique            NaN                   19            NaN                2
# top               NaN  12ª RISP - Ipatinga            NaN        Masculino
# freq              NaN                28882            NaN           253692
# mean         9.558595                  NaN       0.771633              NaN
# std          5.098901                  NaN       0.419781              NaN
# min          1.000000                  NaN       0.000000              NaN
# 25%          5.000000                  NaN       1.000000              NaN
# 50%         10.000000                  NaN       1.000000              NaN
# 75%         14.000000                  NaN       1.000000              NaN
# max         19.000000                  NaN       1.000000              NaN
#
#         COD_ESCOLARIDADE_NA_ADMISSAO ESCOLARIDADE_NA_ADMISSAO            ANO  \
# count                  328773.000000                   328773  328773.000000
# unique                           NaN                       13            NaN
# top                              NaN        1.Grau Incompleto            NaN
# freq                             NaN                    51110            NaN
# mean                       14.404553                      NaN    2020.240008
# std                        29.346173                      NaN       2.211549
# min                         1.000000                      NaN    2017.000000
# 25%                         3.000000                      NaN    2018.000000
# 50%                         5.000000                      NaN    2020.000000
# 75%                         7.000000                      NaN    2022.000000
# max                        99.000000                      NaN    2024.000000
#
#          MES_NUMERICO   CONTAGEM_IPL
# count   328773.000000  328773.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean         4.851527      18.775137
# std          3.824150      67.361858
# min          1.000000       0.000000
# 25%          1.000000       1.000000
# 50%          4.000000       3.000000
# 75%          8.000000      11.000000
# max         12.000000    1422.000000

# %%
#Verificando se há dados ausentes:
df.isna().sum()
# Out:
# COD_OBSERVATORIO                0
# NOME_ESTAB_PRISIONAL            0
# COD_INSTITUICAO                 0
# INSTITUICAO                     0
# COD_IBGE                        0
# MUNICIPIO                       0
# COD_RISP                        0
# RISP                            0
# COD_SEXO                        0
# SEXO_NA_ADMISSAO                0
# COD_ESCOLARIDADE_NA_ADMISSAO    0
# ESCOLARIDADE_NA_ADMISSAO        0
# ANO                             0
# MES_NUMERICO                    0
# CONTAGEM_IPL                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['COD_OBSERVATORIO', 'NOME_ESTAB_PRISIONAL', 'COD_INSTITUICAO',
#        'INSTITUICAO', 'COD_IBGE', 'MUNICIPIO', 'COD_RISP', 'RISP', 'COD_SEXO',
#        'SEXO_NA_ADMISSAO', 'COD_ESCOLARIDADE_NA_ADMISSAO',
#        'ESCOLARIDADE_NA_ADMISSAO', 'ANO', 'MES_NUMERICO', 'CONTAGEM_IPL'],
#       dtype='object')

# %%
#verificando duplicatas:
df.duplicated().sum()
# Out:
# np.int64(44146)

# %%
df = df.drop_duplicates()

# %%
#número de dados após a retirada das duplicações:
print(f"Número de registros após limpeza: {len(df)}")
# Out:
# Número de registros após limpeza: 284627

# %%
#padronizando o nome das colunas:
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['cod_observatorio', 'nome_estab_prisional', 'cod_instituicao',
#        'instituicao', 'cod_ibge', 'municipio', 'cod_risp', 'risp', 'cod_sexo',
#        'sexo_na_admissao', 'cod_escolaridade_na_admissao',
#        'escolaridade_na_admissao', 'ano', 'mes_numerico', 'contagem_ipl'],
#       dtype='object')

# %%
df.head(10)  # mostra as 10 primeiras linhas
# Out:
#     cod_observatorio                 nome_estab_prisional  cod_instituicao  \
# 0              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 4              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 7              40159  Anexo Prisao Civil Ceresp Gameleira                4
# 13             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 15             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 16             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 17             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 19             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 24             40159  Anexo Prisao Civil Ceresp Gameleira                4
# 26             40159  Anexo Prisao Civil Ceresp Gameleira                4
#
#    instituicao  cod_ibge       municipio  cod_risp                       risp  \
# 0        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 4        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 7        DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 13       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 15       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 16       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 17       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 19       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 24       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
# 26       DEPEN    310620  Belo Horizonte         1  01ª RISP - Belo Horizonte
#
#     cod_sexo sexo_na_admissao  cod_escolaridade_na_admissao  \
# 0          1        Masculino                             1
# 4          1        Masculino                             2
# 7          1        Masculino                             2
# 13         1        Masculino                             3
# 15         1        Masculino                             3
# 16         1        Masculino                             3
# 17         1        Masculino                             3
# 19         1        Masculino                             3
# 24         1        Masculino                             4
# 26         1        Masculino                             4
#
#    escolaridade_na_admissao   ano  mes_numerico  contagem_ipl
# 0                Analfabeto  2017             1             0
# 4         Semi-Alfabetizado  2017             1             0
# 7         Semi-Alfabetizado  2017             1             1
# 13        1.Grau Incompleto  2017             1             0
# 15        1.Grau Incompleto  2017             1             2
# 16        1.Grau Incompleto  2017             1             1
# 17        1.Grau Incompleto  2017             1             6
# 19        1.Grau Incompleto  2017             1             4
# 24          1.Grau Completo  2017             1             0
# 26          1.Grau Completo  2017             1             1

# %%
#verificando outliers:
df_desc = df.describe()
df_desc
# Out:
#        cod_observatorio  cod_instituicao       cod_ibge       cod_risp  \
# count     284627.000000    284627.000000  284627.000000  284627.000000
# mean       42746.885485         4.264016  313786.992604       9.569644
# std         6739.840225         0.677000    2138.501808       5.098797
# min        40002.000000         4.000000  310020.000000       1.000000
# 25%        40074.000000         4.000000  311930.000000       5.000000
# 50%        40132.000000         4.000000  313900.000000      10.000000
# 75%        40201.000000         4.000000  315460.000000      14.000000
# max        60066.000000         6.000000  317200.000000      19.000000
#
#             cod_sexo  cod_escolaridade_na_admissao            ano  \
# count  284627.000000                 284627.000000  284627.000000
# mean        0.761505                     13.908522    2020.205146
# std         0.426164                     28.612518       2.194741
# min         0.000000                      1.000000    2017.000000
# 25%         1.000000                      3.000000    2018.000000
# 50%         1.000000                      5.000000    2020.000000
# 75%         1.000000                      7.000000    2022.000000
# max         1.000000                     99.000000    2024.000000
#
#         mes_numerico   contagem_ipl
# count  284627.000000  284627.000000
# mean        5.448903      21.485702
# std         3.772886      72.009122
# min         1.000000       0.000000
# 25%         2.000000       1.000000
# 50%         5.000000       4.000000
# 75%         9.000000      14.000000
# max        12.000000    1422.000000

# %%
outliers = {}

for col in df.select_dtypes(include='number').columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outlier_count = df[(df[col] < lower_bound) | (df[col] > upper_bound)].shape[0]
    outliers[col] = outlier_count

# Mostrar resultado
for col, count in outliers.items():
    print(f"{col}: {count} outliers")
# Out:
# cod_observatorio: 37573 outliers
# cod_instituicao: 37573 outliers
# cod_ibge: 0 outliers
# cod_risp: 0 outliers
# cod_sexo: 67882 outliers
# cod_escolaridade_na_admissao: 28777 outliers
# ano: 0 outliers
# mes_numerico: 0 outliers
# contagem_ipl: 36287 outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in ['cod_sexo', 'cod_escolaridade_na_admissao', 'contagem_ipl']:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot de {col}')
    plt.show()

# %%
#filtrar e remover outliers:
## iqr = Q3 - Q1
df_desc.loc["IQR"] = df_desc.loc["75%"] - df_desc.loc["25%"]

df_desc
# Out:
#        cod_observatorio  cod_instituicao       cod_ibge       cod_risp  \
# count     284627.000000    284627.000000  284627.000000  284627.000000
# mean       42746.885485         4.264016  313786.992604       9.569644
# std         6739.840225         0.677000    2138.501808       5.098797
# min        40002.000000         4.000000  310020.000000       1.000000
# 25%        40074.000000         4.000000  311930.000000       5.000000
# 50%        40132.000000         4.000000  313900.000000      10.000000
# 75%        40201.000000         4.000000  315460.000000      14.000000
# max        60066.000000         6.000000  317200.000000      19.000000
# IQR          127.000000         0.000000    3530.000000       9.000000
#
#             cod_sexo  cod_escolaridade_na_admissao            ano  \
# count  284627.000000                 284627.000000  284627.000000
# mean        0.761505                     13.908522    2020.205146
# std         0.426164                     28.612518       2.194741
# min         0.000000                      1.000000    2017.000000
# 25%         1.000000                      3.000000    2018.000000
# 50%         1.000000                      5.000000    2020.000000
# 75%         1.000000                      7.000000    2022.000000
# max         1.000000                     99.000000    2024.000000
# IQR         0.000000                      4.000000       4.000000
#
#         mes_numerico   contagem_ipl
# count  284627.000000  284627.000000
# mean        5.448903      21.485702
# std         3.772886      72.009122
# min         1.000000       0.000000
# 25%         2.000000       1.000000
# 50%         5.000000       4.000000
# 75%         9.000000      14.000000
# max        12.000000    1422.000000
# IQR         7.000000      13.000000

# %%
# Comparando antes e depois
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(x=df['contagem_ipl'], ax=axes[0])
axes[0].set_title('Antes da filtragem')

sns.boxplot(x=df_filtrado['contagem_ipl'], ax=axes[1])
axes[1].set_title('Depois da filtragem')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3454749771.py in <cell line: 0>()
#       4 axes[0].set_title('Antes da filtragem')
#       5
# ----> 6 sns.boxplot(x=df_filtrado['contagem_ipl'], ax=axes[1])
#       7 axes[1].set_title('Depois da filtragem')
#       8
#
# NameError: name 'df_filtrado' is not defined

# %%
# visualizando distribuições com histogramas para ter intuição quanto a outliers
for col in df:

    sns.histplot(data=df, x=col, kde=True).set_title(f"Distribuição da variável {col}")
    plt.show()

# %%
#Verificando valores únicos e inconsistências:
print(df['sexo_na_admissao'].value_counts())

# %%
print(df['escolaridade_na_admissao'].value_counts())

# %%
print(df.columns.tolist())

# %%
df['escolaridade_na_admissao'] = df['escolaridade_na_admissao'].str.strip().str.title()

df['escolaridade_na_admissao'] = df['escolaridade_na_admissao'].replace({
    '1.Grau Incompleto': 'Fundamental Incompleto',
    '2.Grau Incompleto': 'Fundamental Incompleto',
    '1.Grau Completo': 'Fundamental Completo',
    '2.Grau Completo': 'Fundamental Completo',
    'Semi-Alfabetizado': 'Semi-Alfabetizado',
    'Sem Informação': 'Sem Informação',
    'Analfabeto': 'Analfabeto',
    'Superior Incompleto': 'Superior Incompleto',
    'Superior Completo': 'Superior Completo',
    'Pós-Graduado': 'Pós-Graduado',
    'Pos Doutorado': 'Pós-Doutorado',
    'Mestrado': 'Mestrado',
    'Doutorado': 'Doutorado'
})

# %%
df['escolaridade_na_admissao'].value_counts()

# %%
escolaridade_counts = df['escolaridade_na_admissao'].value_counts()

# %%
# Criar gráfico de barras horizontal
plt.figure(figsize=(10, 6))
escolaridade_counts.plot(kind='barh', color='mediumslateblue')

# Títulos e rótulos
plt.title('Distribuição da Escolaridade na Admissão', fontsize=14)
plt.xlabel('Número de Pessoas', fontsize=12)
plt.ylabel('Escolaridade', fontsize=12)
plt.gca().invert_yaxis()  # Coloca a maior categoria no topo
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
print(df['instituicao'].value_counts())

# %%
# Contagem das instituições
instituicoes = df['instituicao'].value_counts()

# %%
# Gráfico de barras
plt.figure(figsize=(6, 4))
instituicoes.plot(kind='bar', color=['steelblue', 'orange'])

# Títulos e rótulos
plt.title('Distribuição por Tipo de Instituição Prisional', fontsize=14)
plt.xlabel('Instituição', fontsize=12)
plt.ylabel('Número de Pessoas', fontsize=12)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#Cruzando informações:
tabela_cruzada = df.groupby(['instituicao', 'escolaridade_na_admissao']).size().unstack().fillna(0)
tabela_cruzada

# %%
#Gráfico com as informações cruzadas:
tabela_cruzada.T.plot(kind='bar', stacked=True, figsize=(12,6), colormap='tab20')

plt.title('Escolaridade na Admissão por Tipo de Instituição')
plt.xlabel('Escolaridade')
plt.ylabel('Número de Pessoas')
plt.legend(title='Instituição')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
